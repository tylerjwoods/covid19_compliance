# %%
import cv2

# %%
# clip_path = '../test_videos/'
# video_file = 'tyler1.mp4'

# vidcap = cv2.VideoCapture('{}{}'.format(clip_path, video_file))

# %%
#vidcap
# Out:
# <VideoCapture 0x7efe9b0454d0>

# %%
# success,image = vidcap.read()

# %%
# success
# Out:
# True

# %%
image.shape
# Out:
# (720, 1080, 3)

# %%
clip_path = '../test_videos/'
video_file = 'tyler1.mp4'

vidcap = cv2.VideoCapture('{}{}'.format(clip_path, video_file))

success,frame = vidcap.read()

writer = None

count = 0
while success:
    success, frame = vidcap.read()
    save_path = 'frames_test/{}_frame.jpg'
    cv2.imwrite(save_path.format(count), frame)
    count += 1
    
    if count == 3:
        break
    # check if the video writer is None
    if writer is None:
        # initialize our video writer
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")
        writer = cv2.VideoWriter('video_test/', fourcc, 30,
            (W, H), True)
    # write the output frame to disk
    writer.write(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1d354b4d4abe> in <module>
#      22         fourcc = cv2.VideoWriter_fourcc(*"MJPG")
#      23         writer = cv2.VideoWriter('video_test/', fourcc, 30,
# ---> 24             (W, H), True)
#      25     # write the output frame to disk
#      26     writer.write(output)
#
# NameError: name 'W' is not defined

# %%
from collections import deque

# %%
Q = deque(maxlen = 128)

# %%
Q
# Out:
# deque([])

# %%
a = 'test_videos/tyler1.mp4'
a[12:-4]
# Out:
# 'tyler1'

# %%
startX = 5
endX = 20
startY = 3
endY = 50

# %%
(max(startX - endX, startY - endY))
# Out:
# -15

# %%
cv2.circle(image, (int((startX + endX)/2)), (int((startY + endY)/2)), 
                       int(max(endX - startX, endY - startY)), color, 8)
